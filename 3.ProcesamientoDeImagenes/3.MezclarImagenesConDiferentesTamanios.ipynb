# %%
import matplotlib.pyplot as plt
import cv2

# %%
#Opencv usa el formato BGR y el matplotlib usa RGB
imagenOriginal=cv2.imread("D:\CursoOpenCV\Imagenes\Yukino.jpg")
imagenOriginal=cv2.cvtColor(imagenOriginal,cv2.COLOR_BGR2RGB)
plt.imshow(imagenOriginal)

# %%
imagenOriginal2=cv2.imread("D:\CursoOpenCV\Imagenes\Hikki.jpg")
imagenOriginal2=cv2.cvtColor(imagenOriginal2,cv2.COLOR_BGR2RGB)
plt.imshow(imagenOriginal2)

# %%
imagenOriginal.shape
# Out:
# (1264, 1945, 3)

# %%
imagenOriginal2.shape
# Out:
# (400, 400, 3)

# %%
valores=imagenOriginal.shape
valor=valores[1]-1250
valor
# Out:
# 695

# %%
imagenOriginal2=cv2.resize(imagenOriginal2,(valor,1264))
plt.imshow(imagenOriginal2)

# %%
# imagen[fila inicial : fila final, columna inicial : columna final]
imagenRecortada=imagenOriginal[0:1264,1250:1945]
plt.imshow(imagenRecortada)

# %%
imagenOriginal2.shape
# Out:
# (1264, 695, 3)

# %%
imagenRecortada.shape
# Out:
# (1264, 695, 3)

# %%
#cv2.addWeighted(src1=IMAGEN,alpha=PESO,src2=IMAGEN,beta=PESO)
imagenUnida=cv2.addWeighted(src1=imagenRecortada,alpha=0.4,src2=imagenOriginal2,beta=0.6,gamma=0)
plt.imshow(imagenUnida)

# %%
imagenOriginal[:,1250:]=imagenUnida
plt.imshow(imagenOriginal)

# %%
imagenOriginal=cv2.cvtColor(imagenOriginal,cv2.COLOR_RGB2BGR)
cv2.imwrite('D:\CursoOpenCV\Imagenes\YukinoHachi.jpg',imagenOriginal)
# Out:
# True
